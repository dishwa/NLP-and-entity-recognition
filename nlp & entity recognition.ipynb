# %%
# !pip install nltk
# !pip install spacy
# !python -m spacy download en_core_web_sm
import nltk
nltk.download('punkt')
# Out:
# ...
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
text = "Mumbai or Bombay is the capital city of the Indian State of Maharashtra. According to the United Nations, as of 2018, Mumbai was the second most populated city in India after Delhi. In the world with a population of roughly 20 million. As per the Indian government population census of 2011, Mumbai was the most populated city in India. An estimated city-proper population of 12.5 million living under the Municipal Corporation of Greater Mumbai."
# sentence tokenization
sentences = nltk.sent_tokenize(text)
for sentence in sentences:
    print(sentence)
# Out:
# Mumbai or Bombay is the capital city of the Indian State of Maharashtra.
# According to the United Nations, as of 2018, Mumbai was the second most populated city in India after Delhi.
# In the world with a population of roughly 20 million.
# As per the Indian government population census of 2011, Mumbai was the most populated city in India.
# An estimated city-proper population of 12.5 million living under the Municipal Corporation of Greater Mumbai.

# %%
# word tokenization
# white space tokenization
for sentence in sentences:
    words = nltk.word_tokenize(sentence)
    print(words)
# Out:
# ['Mumbai', 'or', 'Bombay', 'is', 'the', 'capital', 'city', 'of', 'the', 'Indian', 'State', 'of', 'Maharashtra', '.']
# ['According', 'to', 'the', 'United', 'Nations', ',', 'as', 'of', '2018', ',', 'Mumbai', 'was', 'the', 'second', 'most', 'populated', 'city', 'in', 'India', 'after', 'Delhi', '.']
# ['In', 'the', 'world', 'with', 'a', 'population', 'of', 'roughly', '20', 'million', '.']
# ['As', 'per', 'the', 'Indian', 'government', 'population', 'census', 'of', '2011', ',', 'Mumbai', 'was', 'the', 'most', 'populated', 'city', 'in', 'India', '.']
# ['An', 'estimated', 'city-proper', 'population', 'of', '12.5', 'million', 'living', 'under', 'the', 'Municipal', 'Corporation', 'of', 'Greater', 'Mumbai', '.']

# %%
# stemming
from nltk.stem import PorterStemmer
ps = PorterStemmer()
for sentence in sentences:
    words = nltk.word_tokenize(sentence)
    for word in words:
        rootWord = ps.stem(word)
        print("Root of ", word, "is ", rootWord)
# Out:
# Root of  Mumbai is  mumbai
# Root of  or is  or
# Root of  Bombay is  bombay
# Root of  is is  is
# Root of  the is  the
# Root of  capital is  capit
# Root of  city is  citi
# Root of  of is  of
# Root of  the is  the
# Root of  Indian is  indian
# Root of  State is  state
# Root of  of is  of
# Root of  Maharashtra is  maharashtra
# Root of  . is  .
# Root of  According is  accord
# Root of  to is  to
# Root of  the is  the
# Root of  United is  unit
# Root of  Nations is  nation
# Root of  , is  ,
# Root of  as is  as
# Root of  of is  of
# Root of  2018 is  2018
# Root of  , is  ,
# Root of  Mumbai is  mumbai
# Root of  was is  wa
# Root of  the is  the
# Root of  second is  second
# Root of  most is  most
# Root of  populated is  popul
# Root of  city is  citi
# Root of  in is  in
# Root of  India is  india
# Root of  after is  after
# Root of  Delhi is  delhi
# Root of  . is  .
# Root of  In is  in
# Root of  the is  the
# Root of  world is  world
# Root of  with is  with
# ...

# %%
# lemmatization
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('omw-1.4')
wordnet_lemmatizer = WordNetLemmatizer()
for sentence in sentences:
    words = nltk.word_tokenize(sentence)
    for word in words:
        rootWord = wordnet_lemmatizer.lemmatize(word)
        print("Lemma of ", word, "is ", rootWord)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Lemma of  Mumbai is  Mumbai
# Lemma of  or is  or
# Lemma of  Bombay is  Bombay
# Lemma of  is is  is
# Lemma of  the is  the
# Lemma of  capital is  capital
# Lemma of  city is  city
# Lemma of  of is  of
# Lemma of  the is  the
# Lemma of  Indian is  Indian
# Lemma of  State is  State
# Lemma of  of is  of
# Lemma of  Maharashtra is  Maharashtra
# Lemma of  . is  .
# Lemma of  According is  According
# Lemma of  to is  to
# Lemma of  the is  the
# Lemma of  United is  United
# Lemma of  Nations is  Nations
# Lemma of  , is  ,
# Lemma of  as is  a
# Lemma of  of is  of
# Lemma of  2018 is  2018
# Lemma of  , is  ,
# Lemma of  Mumbai is  Mumbai
# ...

# %%
# print stop words
nltk.download('stopwords')
from nltk.corpus import stopwords
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
# stop word removal
#abc=['Mumbai']
stop_words = stopwords.words('english')
#stop_words.extend(abc) # add a list of words to stop word list
#stop_words.remove(abc) # remove a list of words from stop word list
text_tokens = nltk.word_tokenize(text)
tokens_without_sw = [word for word in text_tokens if not word in stop_words]
print(tokens_without_sw)
# Out:
# ['Mumbai', 'Bombay', 'capital', 'city', 'Indian', 'State', 'Maharashtra', '.', 'According', 'United', 'Nations', ',', '2018', ',', 'Mumbai', 'second', 'populated', 'city', 'India', 'Delhi', '.', 'In', 'world', 'population', 'roughly', '20', 'million', '.', 'As', 'per', 'Indian', 'government', 'population', 'census', '2011', ',', 'Mumbai', 'populated', 'city', 'India', '.', 'An', 'estimated', 'city-proper', 'population', '12.5', 'million', 'living', 'Municipal', 'Corporation', 'Greater', 'Mumbai', '.']

# %%
# part of speech tagging - with visualization
import spacy
from spacy import displacy
sp = spacy.load('en_core_web_sm')
for sentence in sentences:
    sen = sp(sentence)
    displacy.render(sen, style = 'dep', jupyter = True, options = {'distance': 85})
#127.0.0.1:5000(or any other potr shown in output instead of 5000)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3feeed41ffa2442e97fa666b266144bb-0" class="displacy" width="1155" height="264.5" direction="ltr" style="max-width: none; height: 264.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Mumbai</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
#     <tspan class="displacy-word" fill="currentColor" x="135">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="135">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="174.5">
# ...

# %%
# named entity recognition
sen = sp(text)
print(sen.ents)
# Out:
# (Mumbai, Bombay, the Indian State of Maharashtra, the United Nations, 2018, Mumbai, second, India, Delhi, roughly 20 million, Indian, 2011, Mumbai, India, 12.5 million, the Municipal Corporation of Greater Mumbai)

# %%
sen = sp(text)
for entity in sen.ents:
    print(entity.text + ' - ' + entity.label_ + ' - ' + str(spacy.explain(entity.label_)))
# Out:
# Mumbai - GPE - Countries, cities, states
# Bombay - GPE - Countries, cities, states
# the Indian State of Maharashtra - GPE - Countries, cities, states
# the United Nations - ORG - Companies, agencies, institutions, etc.
# 2018 - DATE - Absolute or relative dates or periods
# Mumbai - GPE - Countries, cities, states
# second - ORDINAL - "first", "second", etc.
# India - GPE - Countries, cities, states
# Delhi - GPE - Countries, cities, states
# roughly 20 million - CARDINAL - Numerals that do not fall under another type
# Indian - NORP - Nationalities or religious or political groups
# 2011 - DATE - Absolute or relative dates or periods
# Mumbai - GPE - Countries, cities, states
# India - GPE - Countries, cities, states
# 12.5 million - CARDINAL - Numerals that do not fall under another type
# the Municipal Corporation of Greater Mumbai - ORG - Companies, agencies, institutions, etc.

# %%
len([ent for ent in sen.ents if ent.label_ == 'GPE'])
# Out:
# 8

# %%
displacy.render(sen, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mumbai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  or
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bombay
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is the capital city of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Indian State of Maharashtra
# ...
